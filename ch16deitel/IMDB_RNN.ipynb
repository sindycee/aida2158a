# %% [markdown]
# # Section 16.10

# %%
from keras.datasets import imdb
# Out:
# WARNING:tensorflow:From e:\anaconda3\envs\aida2158a\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
number_of_words = 10000

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=number_of_words)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 6s 0us/step

# %%
X_train.shape
# Out:
# (25000,)

# %%
y_train.shape
# Out:
# (25000,)

# %%
X_test.shape
# Out:
# (25000,)

# %%
y_test.shape
# Out:
# (25000,)

# %%
# %pprint
# Out:
# Pretty printing has been turned OFF

# %%
X_train[123]
# Out:
# [1, 307, 5, 1301, 20, 1026, 2511, 87, 2775, 52, 116, 5, 31, 7, 4, 91, 1220, 102, 13, 28, 110, 11, 6, 137, 13, 115, 219, 141, 35, 221, 956, 54, 13, 16, 11, 2714, 61, 322, 423, 12, 38, 76, 59, 1803, 72, 8, 2, 23, 5, 967, 12, 38, 85, 62, 358, 99]

# %%
word_to_index = imdb.get_word_index()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1641221/1641221 [==============================] - 0s 0us/step

# %%
word_to_index['great']
# Out:
# 84

# %%
index_to_word = \
    {index: word for (word, index) in word_to_index.items()}

# %%
[index_to_word[i] for i in range(1, 51)]
# Out:
# ['the', 'and', 'a', 'of', 'to', 'is', 'br', 'in', 'it', 'i', 'this', 'that', 'was', 'as', 'for', 'with', 'movie', 'but', 'film', 'on', 'not', 'you', 'are', 'his', 'have', 'he', 'be', 'one', 'all', 'at', 'by', 'an', 'they', 'who', 'so', 'from', 'like', 'her', 'or', 'just', 'about', "it's", 'out', 'has', 'if', 'some', 'there', 'what', 'good', 'more']

# %%
' '.join([index_to_word.get(i - 3, '?') for i in X_train[123]])
# Out:
# '? beautiful and touching movie rich colors great settings good acting and one of the most charming movies i have seen in a while i never saw such an interesting setting when i was in china my wife liked it so much she asked me to ? on and rate it so other would enjoy too'

# %%
y_train[123]
# Out:
# 1

# %%
words_per_review = 200

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
X_train = pad_sequences(X_train, maxlen=words_per_review)

# %%
X_train.shape
# Out:
# (25000, 200)

# %%
X_test = pad_sequences(X_test, maxlen=words_per_review)

# %%
X_test.shape
# Out:
# (25000, 200)

# %%
from sklearn.model_selection import train_test_split
X_test, X_val, y_test, y_val = train_test_split(
    X_test, y_test, random_state=11, test_size=0.20)

# %%
X_test.shape
# Out:
# (20000, 200)

# %%
X_val.shape
# Out:
# (5000, 200)

# %%
from tensorflow.keras.models import Sequential

# %%
rnn = Sequential()
# Out:
# WARNING:tensorflow:From e:\anaconda3\envs\aida2158a\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
from keras.layers import Dense, LSTM

# %%
from keras.layers import Embedding

# %%
rnn.add(Embedding(input_dim=number_of_words, output_dim=128,
                  input_length=words_per_review))

# %%
rnn.add(LSTM(units=128, dropout=0.2, recurrent_dropout=0.2))

# %%
rnn.add(Dense(units=1, activation='sigmoid'))

# %%
rnn.compile(optimizer='adam',
            loss='binary_crossentropy', 
            metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From e:\anaconda3\envs\aida2158a\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
rnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 200, 128)          1280000
#
#  lstm (LSTM)                 (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 1411713 (5.39 MB)
# Trainable params: 1411713 (5.39 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
rnn.fit(X_train, y_train, epochs=5, batch_size=32, validation_data=(X_val, y_val))
# Out:
# Epoch 1/5
# WARNING:tensorflow:From e:\anaconda3\envs\aida2158a\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From e:\anaconda3\envs\aida2158a\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 782/782 [==============================] - 315s 400ms/step - loss: 0.4399 - accuracy: 0.8028 - val_loss: 0.4332 - val_accuracy: 0.8076
# Epoch 2/5
# 782/782 [==============================] - 255s 326ms/step - loss: 0.2895 - accuracy: 0.8835 - val_loss: 0.3613 - val_accuracy: 0.8586
# Epoch 3/5
# 782/782 [==============================] - 293s 375ms/step - loss: 0.2101 - accuracy: 0.9194 - val_loss: 0.3792 - val_accuracy: 0.8584
# Epoch 4/5
# 782/782 [==============================] - 237s 303ms/step - loss: 0.1627 - accuracy: 0.9383 - val_loss: 0.4636 - val_accuracy: 0.8468
# Epoch 5/5
# 782/782 [==============================] - 240s 307ms/step - loss: 0.1409 - accuracy: 0.9461 - val_loss: 0.4056 - val_accuracy: 0.8538

# %%
results = rnn.evaluate(X_test, y_test)
# Out:
# 625/625 [==============================] - 21s 34ms/step - loss: 0.3970 - accuracy: 0.8530

# %%
results
# Out:
# [0.39695000648498535, 0.8529999852180481]

# %%
##########################################################################
# (C) Copyright 2019 by Deitel & Associates, Inc. and                    #
# Pearson Education, Inc. All Rights Reserved.                           #
#                                                                        #
# DISCLAIMER: The authors and publisher of this book have used their     #
# best efforts in preparing the book. These efforts include the          #
# development, research, and testing of the theories and programs        #
# to determine their effectiveness. The authors and publisher make       #
# no warranty of any kind, expressed or implied, with regard to these    #
# programs or to the documentation contained in these books. The authors #
# and publisher shall not be liable in any event for incidental or       #
# consequential damages in connection with, or arising out of, the       #
# furnishing, performance, or use of these programs.                     #
##########################################################################
