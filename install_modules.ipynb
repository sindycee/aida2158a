# %% [markdown]
# **Note:** It is recommended that you install these libraries within a Conda environment (e.g., `aida2158a`). These libraries are required for *Murach’s Python for Data Science, 2nd Edition*.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Alternatively, install the libraries here.

# %%
pip install numpy==1.26.4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install urllib3==2.1.0
# Out:
# ...
#   Using cached urllib3-2.1.0-py3-none-any.whl.metadata (6.4 kB)
# Using cached urllib3-2.1.0-py3-none-any.whl (104 kB)
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.6.2
#     Uninstalling urllib3-2.6.2:
#       Successfully uninstalled urllib3-2.6.2
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install datetime==5.4
# Out:
# ...
#   Using cached DateTime-5.4-py3-none-any.whl.metadata (33 kB)
# ...
#   Using cached zope_interface-8.1.1-cp310-cp310-win_amd64.whl.metadata (46 kB)
# ...
# Using cached DateTime-5.4-py3-none-any.whl (52 kB)
# Using cached zope_interface-8.1.1-cp310-cp310-win_amd64.whl (211 kB)
# ...
#
#    ---------------------------------------- 0/2 [zope.interface]
#    ---------------------------------------- 0/2 [zope.interface]
#    ---------------------------------------- 0/2 [zope.interface]
#    ---------------------------------------- 0/2 [zope.interface]
#    -------------------- ------------------- 1/2 [datetime]
#    ---------------------------------------- 2/2 [datetime]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas==2.2.0
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn==0.13.2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopandas==0.14.3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn==1.4.1.post1
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyreadstat==1.2.6
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyarrow==15.0.0
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl==3.1.2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install statsmodels==0.14.1
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib==3.8.3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import sys
print(sys.executable)
# Out:
# e:\anaconda3\envs\aida2158a\python.exe

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import geopandas as gpd
import sklearn
import pyarrow as pa
import statsmodels
import openpyxl
import pyreadstat
import urllib3
import datetime
import torch
import sys

print("Python:", sys.version)
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Seaborn:", sns.__version__)
print("GeoPandas:", gpd.__version__)
print("Scikit-learn:", sklearn.__version__)
print("PyArrow:", pa.__version__)
print("Statsmodels:", statsmodels.__version__)
print("OpenPyXL:", openpyxl.__version__)
print("PyReadStat:", pyreadstat.__version__)
print("urllib3:", urllib3.__version__)
print("datetime: standard library (built-in)")
print("Torch:", torch.__version__)
print("Torch CUDA available:", torch.cuda.is_available())
# Out:
# Python: 3.10.19 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 16:41:31) [MSC v.1929 64 bit (AMD64)]
# NumPy: 1.26.4
# Pandas: 2.2.0
# Seaborn: 0.13.2
# GeoPandas: 0.14.3
# Scikit-learn: 1.4.1.post1
# PyArrow: 15.0.0
# Statsmodels: 0.14.1
# OpenPyXL: 3.1.2
# PyReadStat: 1.2.6
# urllib3: 2.6.2
# datetime: standard library (built-in)
# Torch: 2.3.1
# Torch CUDA available: False

# %% [markdown]
# The aida2158a Conda environment is correctly configured, fully compatible with Python 3.10, and ready for linear regression, MLP regression, visualization, and evaluation in Jupyter Notebook.

# %% [markdown]
# Installed tensorflow, keras.

# %%
pip install tensorflow==2.15.1 keras==2.15.0 tensorflow-datasets

# %%
import tensorflow as tf
import keras
import tensorflow_datasets as tfds

print(tf.__version__)
print(keras.__version__)
print(tfds.__version__)
# Out:
# WARNING:tensorflow:From e:\anaconda3\envs\aida2158a\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 2.15.1
# 2.15.0
# 4.9.9
